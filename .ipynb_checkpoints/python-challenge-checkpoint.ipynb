# %% [markdown]
# # Python challenges
# All the challenges from python challenge solved. Web -> http://www.pythonchallenge.com

# %% [markdown]
# ### Challenge 0 - warming up
# Link: http://www.pythonchallenge.com/pc/def/0.html
# <img src="c0/calc.jpg">
#
# Hint: try to change the URL address.

# %%
2**38
# Out:
# 274877906944

# %% [markdown]
# Then you go to http://www.pythonchallenge.com/pc/def/274877906944.html and it redirects you to the next challenge url.

# %% [markdown]
# ### Challenge 1 - What about making trans?
# Link: http://www.pythonchallenge.com/pc/def/map.html
# <img src="c1/map.jpg">
#
# everybody thinks twice before solving this.
#
# g fmnc wms bgblr rpylqjyrc gr zw fylb. rfyrq ufyr amknsrcpq ypc dmp. bmgle gr gl zw fylb gq glcddgagclr ylb rfyr'q ufw rfgq rcvr gq qm jmle. sqgle qrpgle.kyicrpylq() gq pcamkkclbcb. lmu ynnjw ml rfc spj.

# %% [markdown]
# The first step is to get the data to a variable.

# %%
input_string = "g fmnc wms bgblr rpylqjyrc gr zw fylb. rfyrq ufyr amknsrcpq ypc dmp. bmgle gr gl zw fylb gq glcddgagclr ylb rfyr'q ufw rfgq rcvr gq qm jmle. sqgle qrpgle.kyicrpylq() gq pcamkkclbcb. lmu ynnjw ml rfc spj."

# %% [markdown]
# We realize that there's a 2 character difference between the character pairs so we try to move 2 positions every char

# %%
# We check if every character is a letter
# from a-z and if it is we shift it 2 positions in 
# the abc and store it in a new string.
sol=""
for ch in input_string:
    n = ord(ch)
    # 96 is the ascii code for a and 123 for z
    if (n>96) and (n<123):
        # since it is circular (z->b) we need to take it into account
        sol += chr((n - 96 + 2)%26 + 96)
    else:
        sol += chr(n)
print(sol)
# Out:
# i hope you didnt translate it by hand. thats what computers are for. doing it in by hand is inefficient and that's why this text is so long. using string.maketrans() is recommended. now apply on the url.

# %% [markdown]
# So we try the same on the url...

# %%
# Since here there are only letters we don't need to check
# it. And also there's no edge cases (y,z)
sol = ""
for ch in "map":
    n = ord(ch)
    sol += chr(ord(ch) + 2)
print(sol)
# Out:
# ocr

# %% [markdown]
# ### Challenge 2 - ocr
# Link: http://www.pythonchallenge.com/pc/def/ocr.html
# <img src="c2/ocr.jpg">
#
# recognize the characters. maybe they are in the book,
# but MAYBE they are in the page source.

# %% [markdown]
# Inspecting the source code we see that there is a huge string of strange symbols and some letters. First step is to get that in a var.

# %%
from urllib.request import urlopen
import re

html=urlopen("http://www.pythonchallenge.com/pc/def/ocr.html").read().decode()
# Since the string is surrounded by comment symbols we can regex that
input_string = re.findall(r'<!--[^-->]*-->',str(html))[0][5:-3]
# Two line sample
print(input_string[:160])
# Out:
# %%$@_$^__#)^)&!_+]!*@&^}@[@%]()%+$&[(_@%+%$*^@$^!+]!&_#)_*}{}}!}_]$[%}@[{_@#_^{*
# @##&{#&{&)*%(]{{([*}@[@&]+!!*{)!}{%+{))])[!^})+)$]#{*+^((@^@}$[**$&^{$!@#$%)!@(

# %% [markdown]
# Then we keep only the letters and see what we get

# %%
sol=""
for ch in input_string:
    n = ord(ch)
    if (n>96) and (n<123):
        sol += ch
print(sol)
# Out:
# equality

# %% [markdown]
# ### Challenge 3 - re
# <img src="c3/bodyguard.jpg">
#
# One small letter, surrounded by EXACTLY three big bodyguards on each of its sides.

# %% [markdown]
# Looking at see source code we see something similar to the previous challenge, a huge string in the comments. First step get that in a var.

# %%
from urllib.request import urlopen
import re

html=urlopen("http://www.pythonchallenge.com/pc/def/equality.html").read().decode()
# Since the string is surrounded by comment symbols we can regex that
input_string = re.findall(r'<!--[^-->]*-->',str(html))[0][5:-3]
# Two line sample
print(input_string[:160])
# Out:
# kAewtloYgcFQaJNhHVGxXDiQmzjfcpYbzxlWrVcqsmUbCunkfxZWDZjUZMiGqhRRiUvGmYmvnJIHEmbT
# MUKLECKdCthezSYBpIElRnZugFAxDRtQPpyeCBgBfaRVvvguRXLvkAdLOeCKxsDUvBBCwdpMMWmuELe

# %% [markdown]
# The next is to look for exactly what the hint says, look for a lower case letter surrounded by 3 upper case words.

# %%
import re
matches = re.findall(r'[a-z][A-Z]{3}[a-z][A-Z]{3}[a-z]', input_string)
print(matches)
# Out:
# ['qIQNlQSLi', 'eOEKiVEYj', 'aZADnMCZq', 'bZUTkLYNg', 'uCNDeHSBj', 'kOIXdKBFh', 'dXJVlGZVm', 'gZAGiLQZx', 'vCJAsACFl', 'qKWGtIDCj']

# %% [markdown]
# Aparently this is nonsense, but looking closely you realize that there's the result in there...

# %%
[res[4] for res in matches]
# Out:
# ['l', 'i', 'n', 'k', 'e', 'd', 'l', 'i', 's', 't']

# %% [markdown]
# ### Challenge 4 - follow the chain
# Link: http://www.pythonchallenge.com/pc/def/linkedlist.php
# <img src="c4/chainsaw.jpg">

# %% [markdown]
# When we click the image it takes us to http://www.pythonchallenge.com/pc/def/linkedlist.php?nothing=12345 and we see `and the next nothing is 44827.` Then if you replace 12345 for the 44827 you get a new page with a different number. So here clearly we have to keep going until we find no number...

# %%
from urllib.request import urlopen
import re

base_url = "http://www.pythonchallenge.com/pc/def/linkedlist.php?nothing="
next_num = 12345
while True:
    try:
        next_num = re.findall(r'[0-9]+', urlopen(base_url+str(next_num)).read().decode())[0]
    except:
        print(f"Current number: {next_num}")
        print(urlopen(base_url+str(next_num)).read())
        break
# Out:
# Current number: 16044
# b'Yes. Divide by two and keep going.'

# %% [markdown]
# So we do as it says

# %%
next_num = 16044//2

# %% [markdown]
# And keep going...

# %%
while True:
    try:
        next_num = re.findall(r'[0-9]+', urlopen(base_url+str(next_num)).read().decode())[0]
    except:
        print(f"Current number: {next_num}")
        print(urlopen(base_url+str(next_num)).read())
        break
# Out:
# Current number: 82683
# b"You've been misleaded to here. Go to previous \none and check."

# %% [markdown]
# So next go to none and see...

# %%
next_num = "none"
while True:
    try:
        next_num = re.findall(r'[0-9]+', urlopen(base_url+str(next_num)).read().decode())[0]
    except:
        print(f"Current number: {next_num}")
        print(urlopen(base_url+str(next_num)).read())
        break
# Out:
# Current number: 66831
# b'peak.html'

# %% [markdown]
# ### Challenge 5 - peak hell
# Link: http://www.pythonchallenge.com/pc/def/peak.html
# <img src="c5/peakhell.jpg">
#
# pronounce it

# %% [markdown]
# Here there are two tricks, the first is to realize that peak hell sounds like pickle and that's a python library used for object serialization.
#
# The second is to check the source code and see that there's the line `<peakhell src="banner.p"/>` which suggests going to banner.p and see what we get. In fact we get a file that we can open with the pickle library.

# %%
from urllib.request import urlopen
import pickle

con = urlopen("http://www.pythonchallenge.com/pc/def/banner.p")
data = pickle.load(con)

# %% [markdown]
# The result is a 95x23 matrix expressed in a run length enconding, we can try to print it and see what we get...

# %%
st = ""
for line in data:
    for char in line:
        st += char[0]*char[1]
    st += "\n"
print(st)
# Out:
#
#               #####                                                                      #####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#       ###      ####   ###         ###       #####   ###    #####   ###          ###       ####
#    ###   ##    #### #######     ##  ###      #### #######   #### #######     ###  ###     ####
#   ###     ###  #####    ####   ###   ####    #####    ####  #####    ####   ###     ###   ####
#  ###           ####     ####   ###    ###    ####     ####  ####     ####  ###      ####  ####
#  ###           ####     ####          ###    ####     ####  ####     ####  ###       ###  ####
# ####           ####     ####     ##   ###    ####     ####  ####     #### ####       ###  ####
# ####           ####     ####   ##########    ####     ####  ####     #### ##############  ####
# ####           ####     ####  ###    ####    ####     ####  ####     #### ####            ####
# ####           ####     #### ####     ###    ####     ####  ####     #### ####            ####
#  ###           ####     #### ####     ###    ####     ####  ####     ####  ###            ####
#   ###      ##  ####     ####  ###    ####    ####     ####  ####     ####   ###      ##   ####
#    ###    ##   ####     ####   ###########   ####     ####  ####     ####    ###    ##    ####
#       ###     ######    #####    ##    #### ######    ###########    #####      ###      ######

# %% [markdown]
# ### Challenge 6 - now there are pairs
# Link: http://www.pythonchallenge.com/pc/def/channel.html
# <img src="c6/channel.jpg">

# %% [markdown]
# The first idea is to change the url ending for .zip, so it downloads a zip.

# %%
import urllib.request 
urllib.request.urlretrieve("http://www.pythonchallenge.com/pc/def/channel.zip", "c6/channel.zip")
# Out:
# ('c6/channel.zip', <http.client.HTTPMessage at 0x211ad3eda58>)

# %% [markdown]
# There's a readme file:

# %%
from zipfile import ZipFile
# Load file and read readme
with ZipFile('c6/channel.zip') as myzip:
    with myzip.open('readme.txt') as myfile:
        print(myfile.read().decode())
# Out:
# welcome to my zipped list.
#
# hint1: start from 90052
# hint2: answer is inside the zip

# %% [markdown]
# This is like the previous challenge where you have to keep going until you find the final url. So we do as before...

# %%
import re
# Recursive opening of files
with ZipFile('c6/channel.zip') as myzip:
    file_name = "90052.txt"
    while True:
        myfile = myzip.open(file_name)
        file_content = myfile.read().decode()
        try:
            file_name = re.findall(r'[0-9]+', file_content)[0]+".txt"
        except:
            print(file_content)
            break
# Out:
# Next nothing is 94191

# %% [markdown]
# Reading about the zip standard you see that there is a header field for comments in every file compressed in a zip, so maybe reading them and printing in the order that the tell the files will get us the message...

# %%
import re
# Recursive opening of files
with ZipFile('c6/channel.zip') as myzip:
    file_name = "90052.txt"
    while True:
        myfile = myzip.open(file_name)
        file_content = myfile.read().decode()
        try:
            file_name = re.findall(r'[0-9]+', file_content)[0]+".txt"
            print(myzip.getinfo(file_name).comment.decode(), end="")
        except:
            break
# Out:
# ***************************************************************
# ****************************************************************
# **                                                            **
# **   OO    OO    XX      YYYY    GG    GG  EEEEEE NN      NN  **
# **   OO    OO  XXXXXX   YYYYYY   GG   GG   EEEEEE  NN    NN   **
# **   OO    OO XXX  XXX YYY   YY  GG GG     EE       NN  NN    **
# **   OOOOOOOO XX    XX YY        GGG       EEEEE     NNNN     **
# **   OOOOOOOO XX    XX YY        GGG       EEEEE      NN      **
# **   OO    OO XXX  XXX YYY   YY  GG GG     EE         NN      **
# **   OO    OO  XXXXXX   YYYYYY   GG   GG   EEEEEE     NN      **
# **   OO    OO    XX      YYYY    GG    GG  EEEEEE     NN      **
# **                                                            **
# ****************************************************************
#  **************************************************************

# %% [markdown]
# We are not done yet, when visiting hockey.html appears the next:

# %%
from urllib.request import urlopen
print(urlopen("http://www.pythonchallenge.com/pc/def/"+"hockey.html").read().decode())
# Out:
# it's in the air. look at the letters.

# %% [markdown]
# So guessing a little, we get to oxygen.html

# %% [markdown]
# ### Challenge 7 - smarty
# Link: http://www.pythonchallenge.com/pc/def/oxygen.html
# <img src="c7/oxygen.png">

# %% [markdown]
# In this challenge the first that comes to mind is to read the grayscale values from the middle line and decode it as ascii and see what we get.
#
# Doing a bit of analysis with any image processing software we see that the squares are 7 pixels wide and that the line end at the 610 pixel, se we select that range to analyze it.

# %%
from PIL import Image
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-40-b341a44f930d> in <module>
# ----> 1 from PIL import Image
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'PIL'

# %%
im = cv2.imread("oxygen.png")

# %%
selected = im[48][2:610:7]

# %%
vals = list()
st = ""
for i in range(len(selected)):
    vals.append(selected[i][0])
    st += chr(selected[i][0])

# %%
st
# Out:
# 'smart guy, you made it. the next level is [105, 110, 116, 101, 103, 114, 105, 116, 121]'

# %%
result = [105, 110, 116, 101, 103, 114, 105, 116, 121]

# %%
st = ""
for ch in result:
    st += chr(ch)
print(st)
# Out:
# integrity

# %%
# Challenge 8
un = b'BZh91AY&SYA\xaf\x82\r\x00\x00\x01\x01\x80\x02\xc0\x02\x00 \x00!\x9ah3M\x07<]\xc9\x14\xe1BA\x06\xbe\x084'
pw = b'BZh91AY&SY\x94$|\x0e\x00\x00\x00\x81\x00\x03$ \x00!\x9ah3M\x13<]\xc9\x14\xe1BBP\x91\xf08'

# %%
st = ""
for ch in un:
    st+=str(ord(ch))
un_st = st
st = ""
for ch in pw:
    st+=str(ord(ch))
pw_st = st

# %%
un_st_ex = "0"+un_st

# %%
un_st_ex
# Out:
# '066901045749658938838965175130130011128219220320331541045177760932012022566656190852'

# %%
pw_st
# Out:
# '669010457496589388389148361241400012903363203315410451771960932012022566668014524056'

# %%
-int(un_st)+int(pw_st)
# Out:
# 602109411746930449550183186111270001775143982995078910726783171080010544101358333204

# %%
import bz2

# %%
print(bz2.decompress(un))
print(bz2.decompress(pw))
# Out:
# b'huge'
# b'file'

# %%
# Challenge 9
first = [146,399,163,403,170,393,169,391,166,386,170,381,170,371,170,355,169,346,167,335,170,329,170,320,170,
310,171,301,173,290,178,289,182,287,188,286,190,286,192,291,194,296,195,305,194,307,191,312,190,316,
190,321,192,331,193,338,196,341,197,346,199,352,198,360,197,366,197,373,196,380,197,383,196,387,192,
389,191,392,190,396,189,400,194,401,201,402,208,403,213,402,216,401,219,397,219,393,216,390,215,385,
215,379,213,373,213,365,212,360,210,353,210,347,212,338,213,329,214,319,215,311,215,306,216,296,218,
290,221,283,225,282,233,284,238,287,243,290,250,291,255,294,261,293,265,291,271,291,273,289,278,287,
279,285,281,280,284,278,284,276,287,277,289,283,291,286,294,291,296,295,299,300,301,304,304,320,305,
327,306,332,307,341,306,349,303,354,301,364,301,371,297,375,292,384,291,386,302,393,324,391,333,387,
328,375,329,367,329,353,330,341,331,328,336,319,338,310,341,304,341,285,341,278,343,269,344,262,346,
259,346,251,349,259,349,264,349,273,349,280,349,288,349,295,349,298,354,293,356,286,354,279,352,268,
352,257,351,249,350,234,351,211,352,197,354,185,353,171,351,154,348,147,342,137,339,132,330,122,327,
120,314,116,304,117,293,118,284,118,281,122,275,128,265,129,257,131,244,133,239,134,228,136,221,137,
214,138,209,135,201,132,192,130,184,131,175,129,170,131,159,134,157,134,160,130,170,125,176,114,176,
102,173,103,172,108,171,111,163,115,156,116,149,117,142,116,136,115,129,115,124,115,120,115,115,117,
113,120,109,122,102,122,100,121,95,121,89,115,87,110,82,109,84,118,89,123,93,129,100,130,108,132,110,
133,110,136,107,138,105,140,95,138,86,141,79,149,77,155,81,162,90,165,97,167,99,171,109,171,107,161,
111,156,113,170,115,185,118,208,117,223,121,239,128,251,133,259,136,266,139,276,143,290,148,310,151,
332,155,348,156,353,153,366,149,379,147,394,146,399]

# %%
second = [156,141,165,135,169,131,176,130,187,134,191,140,191,146,186,150,179,155,175,157,168,157,163,157,159,
157,158,164,159,175,159,181,157,191,154,197,153,205,153,210,152,212,147,215,146,218,143,220,132,220,
125,217,119,209,116,196,115,185,114,172,114,167,112,161,109,165,107,170,99,171,97,167,89,164,81,162,
77,155,81,148,87,140,96,138,105,141,110,136,111,126,113,129,118,117,128,114,137,115,146,114,155,115,
158,121,157,128,156,134,157,136,156,136]

# %%
second.extend(second)

# %%
len(second)
# Out:
# 224

# %%
zipped = list(zip(first, second))
a,b = zip(*zipped)

# %%
plt.scatter(first[0::2],first[1::2])

# %%
max(first)
# Out:
# 403

# %%
# Challenge 10
seq = [1, 11, 21, 1211, 111221]

# %%
seq = '1'

# %%
from collections import Counter 
Counter(seq)
# Out:
# Counter({'1': 1})

# %%
seq = "1"
i = 1
print(f"num {i} - {seq}")
dic = Counter(seq) 
while True:
    i += 1
    seq = ""
    for key,val in dic.items():
        seq += f"{val}{key}"
    print(f"num {i} - {seq}")
    dic = Counter(seq)
# Out:
# num 1 - 1
# num 2 - 11
# num 3 - 21
# num 4 - 1211
# num 5 - 3112
# num 6 - 132112
# num 7 - 311322
# num 8 - 232122
# num 9 - 421311
# num 24705 - 32232114
# num 24706 - 23322114
# num 24707 - 32232114
# num 24708 - 23322114
# num 24709 - 32232114
# num 24710 - 23322114
# num 24711 - 32232114
# num 24712 - 23322114
# num 24713 - 32232114
# num 24714 - 23322114
# num 24715 - 32232114
# num 24716 - 23322114
# num 24717 - 32232114
# num 24718 - 23322114
# num 24719 - 32232114
# num 24720 - 23322114
# num 24721 - 32232114
# num 24722 - 23322114
# num 24723 - 32232114
# num 24724 - 23322114
# num 24725 - 32232114
# num 24726 - 23322114
# num 24727 - 32232114
# num 24728 - 23322114
# num 24729 - 32232114
# num 24730 - 23322114
# num 24731 - 32232114
# num 24732 - 23322114
# num 24733 - 32232114
# num 24734 - 23322114
# num 24735 - 32232114
# num 24736 - 23322114
# num 24737 - 32232114
# num 24738 - 23322114
# num 24739 - 32232114
# num 24740 - 23322114
# num 24741 - 32232114
# num 24742 - 23322114
# num 24743 - 32232114
# num 24744 - 23322114
# num 24745 - 32232114
# num 24746 - 23322114
# num 24747 - 32232114
# num 24748 - 23322114
# num 24749 - 32232114
# num 24750 - 23322114
# num 24751 - 32232114
# num 24752 - 23322114
# num 24753 - 32232114
# num 24754 - 23322114
# num 24755 - 32232114
# num 24756 - 23322114
# num 24757 - 32232114
# num 24758 - 23322114
# num 24759 - 32232114
# num 24760 - 23322114
# num 24761 - 32232114
# num 24762 - 23322114
# num 24763 - 32232114
# num 24764 - 23322114
# num 24765 - 32232114
# num 24766 - 23322114
# num 24767 - 32232114
# num 24768 - 23322114
# num 24769 - 32232114
# num 24770 - 23322114
# num 24771 - 32232114
# num 24772 - 23322114
# num 24773 - 32232114
# num 24774 - 23322114
# num 24775 - 32232114
# num 24776 - 23322114
# num 24777 - 32232114
# num 24778 - 23322114
# num 24779 - 32232114
# num 24780 - 23322114
# num 24781 - 32232114
# num 24782 - 23322114
# num 24783 - 32232114
# num 24784 - 23322114
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-170-a9ad08b8fc0e> in <module>
#       8     for key,val in dic.items():
#       9         seq += f"{val}{key}"
# ---> 10     print(f"num {i} - {seq}")
#      11     dic = Counter(seq)
#
# ~\Miniconda3\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # newlines imply flush in subprocesses
#
# ~\Miniconda3\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# ~\Miniconda3\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     398                                  copy_threshold=self.copy_threshold)
#     399             data.group = group
# --> 400         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     401
#     402     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~\Miniconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
len(str(23322114))
# Out:
# 8

# %%
import re

# %%
p = re.compile(r'^([0-9])\1+')
p.search(seq)
# Out:
# <re.Match object; span=(0, 4), match='2222'>

# %%
m.group()
# Out:
# '2222'

# %%
seq = seq[num-1:]

# %%
re.findall( r"(\d)(\1*)", '11122111')
# Out:
# [('1', '11'), ('2', '2'), ('1', '11')]

# %%
seq="1"
#print(seq)
for i in range(30):
    st = ""
    while len(seq)>0:
        m = re.search( r'^([0-9])\1*', seq).group()
        num = len(m)
        seq = seq[num:]
        st += f"{num}{m[0]}"
        #print(f"Match: {m} Number: {num} Seq: {seq}")
    #print(st)
    seq=st
len(st)
# Out:
# 5808

# %% [markdown]
# Next challenge: http://www.pythonchallenge.com/pc/return/5808.html

# %%
# Challenge 11

# %%
from PIL import Image
import numpy as np

# %%
im = Image.open('cave.jpg').convert('LA')
mat = np.array(im)

# %%
Image.fromarray(mat[::2,::2], 'LA')
# Out:
# <PIL.Image.Image image mode=LA size=320x240 at 0x7F3844573DD8>

# %%
pixels

# %%
pixels[(2,2)]
# Out:
# 11

# %%
img = Image.open('cave.jpg').convert('L')

pixels = img.load()
# aaaa
# bueno pos hazlo grande, si se ve algo es un principio
# luego le pones el /2
data = np.zeros((img.height//2, img.width//2)) #works

for i in range(img.width):
    for j in range(img.height):
      # Python se ralla con los booleanos y como que el % tiene preferencia ante el == y cosas asi
            if (j%2 == 0) and (i%2 == 0):
                data[j//2][i//2] = pixels[(i,j)]
            
im = Image.fromarray(data)
im.show()

# %%
type(np.array(img))
# Out:
# numpy.ndarray

# %%
type(data)
# Out:
# numpy.ndarray

# %%
Image.fromarray(data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.7/site-packages/PIL/Image.py in fromarray(obj, mode)
#    2648         out = image1 * (1.0 - alpha) + image2 * alpha
# -> 2649
#    2650     :param im1: The first image.
#
# KeyError: ((1, 1, 3), '<i8')
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-221-aa3d613712f9> in <module>
# ----> 1 Image.fromarray(data)
#
# ~/miniconda3/lib/python3.7/site-packages/PIL/Image.py in fromarray(obj, mode)
#    2649
#    2650     :param im1: The first image.
# -> 2651     :param im2: The second image.  Must have the same mode and size as
#    2652        the first image.
#    2653     :param alpha: The interpolation alpha factor.  If alpha is 0.0, a
#
# TypeError: Cannot handle this data type

# %%
img = Image.open('cave.jpg')

pixels = img.load()
# aaaa
# bueno pos hazlo grande, si se ve algo es un principio
# luego le pones el /2
data = np.zeros((img.height//2, img.width//2, 3), dtype = int) #works

for i in range(img.width):
    for j in range(img.height):
      # Python se ralla con los booleanos y como que el % tiene preferencia ante el == y cosas asi
            if (j%2 == 0) and (i%2 == 0):
                #data[i//2][j//2] = pixels[(i,j)]
                data[j//2,i//2,:] = pixels[(i,j)]
            
im = Image.fromarray(data, 'RGB')
im.show()

# %%
# Challenge 12

# %%
# Read source
f = open('evil2.gfx','rb').read()

# %%
f
# Out:
# b'\xff\x89G\x89\xff\xd8PIP\xd8\xffNFN\xff\xe0G8G\xe0\x00\r7\r\x00\x10\na\n\x10J\x1a@\x1aJF\n\x01\nFI\x00\xf0\x00IF\x00\x00\x00F\x00\x00\xe7\x00\x00\x01\r\x00\r\x01\x01I\x00I\x01\x01H\x00H\x01\x00D\x01D\x00\xb4R\x00R\xb4\x00\x00\x00\x00\x00\xb4\x00\x01\x00\xb4\x00\x01\x04\x01\x00\x00\x90\x02@\x00\xff\x00\x00\x00\xff\xe1\x00\x05\x00\xe1\x08\x01\x00\x00\x0b\xa4,\x02\xf0\xdfE\x08\x00\x08Ex\x02\x06\x02xi\x00\x00\x00if\x00\x00\x00f\x00\x00\x04\x00\x00\x00b\x00\xfe\x00M\xd5\x06OMMr\x00*M\x00\x95\x01<\x00*\x00\x0e\x00*\x00\x00\x00\x00\x00\x00\x00\x03\x00\x00\x00\x06\x06\t\x00\x08b\x01p\x08\x00K\x04H\x00\x00G\x00Y\x00\x00D\x00s\x00\x00\x00\x04\x00\x00\x00\x00\x07\x00\x00\x0e\x00\x05\x1b\x0e\x00\x00\x
#  'system.multicall',
#  'system.getCapabilities']

# %%
s.system.methodHelp('phone')
# Out:
# 'Returns the phone of a person'

# %%
s.phone('Bert')
# Out:
# '555-ITALY'

# %%
# Challenge 13

# %%
from PIL import Image
import numpy as np

# %%
im = Image.open('wire.png').convert('L')
mat = np.array(im)

# %%
mat[:,100:200].shape
# Out:
# (1, 100)

# %%
new = np.zeros((100,100),dtype="uint8")

# %%
for i in range(100):
    new[:,i] = mat[0,(i*100):((i+1)*100)]

# %%
new
# Out:
# array([[178, 178, 178, ..., 183, 183, 183],
#        [183, 182, 182, ...,  71,  72,  72],
#        [ 73,  74,  71, ..., 183, 183, 183],
#        ...,
#        [ 78,  83,  85, ...,  83,  98,  93],
#        [ 93,  88,  84, ..., 105, 107, 106],
#        [ 97,  91,  78, ...,  68,  70,  68]], dtype=uint8)

# %%
im = Image.fromarray(new, 'L')
im
# Out:
# <PIL.Image.Image image mode=L size=100x100 at 0x224C7912940>

# %%
new = np.zeros((3,3),dtype="uint8")

# %%
new
# Out:
# array([[0, 1, 0],
#        [0, 2, 0],
#        [0, 3, 0]], dtype=uint8)

# %%
new[3:1,1] = test
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-e7b0aac4f080> in <module>
# ----> 1 new[3:1,1] = test
#
# ValueError: could not broadcast input array from shape (3) into shape (0)

# %%
test = np.array((1,2,3))

# %%
test
# Out:
# array([1, 2, 3])

# %%
np.rot90(test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-b6130f25fd24> in <module>
# ----> 1 np.rot90(test)
#
# ~\Miniconda3\lib\site-packages\numpy\lib\function_base.py in rot90(m, k, axes)
#     133
#     134     if axes[0] == axes[1] or absolute(axes[0] - axes[1]) == m.ndim:
# --> 135         raise ValueError("Axes must be different.")
#     136
#     137     if (axes[0] >= m.ndim or axes[0] < -m.ndim
#
# ValueError: Axes must be different.

# %%
np.flip(test,0)
# Out:
# array([3, 2, 1])

# %%
mat[0,0:100].shape
# Out:
# (100,)

# %%
n
# Out:
# 100

# %%
pos['x']
# Out:
# 98

# %%
im = Image.open('wire.png')
delta = [(1,0),(0,1),(-1,0),(0,-1)]
out = Image.new('RGB', [100,100])
x,y,p = -1,0,0
d = 200
while d/2>0:
    for v in delta:
        steps = d // 2
        for s in range(steps):
            x, y = x + v[0], y + v[1]
            out.putpixel((x, y),im.getpixel((p,0)))
            p += 1
        d -= 1

# %%
out
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x224C86F26D8>

# %%
n
# Out:
# 98

# %%
pos['y']-(n-2)
# Out:
# 3

# %%
# remember: 100*100 = (100+99+99+98) + (...

# %%
np.flip(pix)
# Out:
# array([182, 182, 182, 183, 183, 183, 183, 181, 181, 183, 183, 184, 184,
#        182, 182, 184, 183, 181, 181, 182, 184, 185, 186, 184, 184, 184,
#        184, 183, 183, 185, 186, 183, 183, 183, 182, 182, 182, 182, 182,
#        181, 181, 181, 181, 181, 181, 181, 181, 181, 181, 181, 181, 181,
#        181, 181,  98,  98,  98,  98,  98, 181, 181, 181,  98, 182, 182,
#        181, 181,  98,  98,  98,  98,  98,  98, 183, 184, 181, 178, 178,
#        177, 177, 178, 176, 176, 180, 183, 182, 179, 181, 181, 180, 180,
#        180, 180, 181, 181, 180, 180, 179], dtype=uint8)
